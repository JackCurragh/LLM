# %%
# !pip install llama-index transformers
# Out:
# Collecting llama-index
#   Downloading llama_index-0.10.45-py3-none-any.whl.metadata (11 kB)
# Collecting transformers
#   Downloading transformers-4.41.2-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 443.6 kB/s eta 0:00:00a 0:00:01
# Collecting llama-index-agent-openai<0.3.0,>=0.1.4 (from llama-index)
#   Downloading llama_index_agent_openai-0.2.7-py3-none-any.whl.metadata (678 bytes)
# Collecting llama-index-cli<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_cli-0.1.12-py3-none-any.whl.metadata (1.5 kB)
# Collecting llama-index-core==0.10.44 (from llama-index)
#   Downloading llama_index_core-0.10.44-py3-none-any.whl.metadata (2.4 kB)
# Collecting llama-index-embeddings-openai<0.2.0,>=0.1.5 (from llama-index)
#   Downloading llama_index_embeddings_openai-0.1.10-py3-none-any.whl.metadata (604 bytes)
# Collecting llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.1.6-py3-none-any.whl.metadata (3.8 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama-index)
#   Downloading llama_index_legacy-0.9.48-py3-none-any.whl.metadata (8.5 kB)
# Collecting llama-index-llms-openai<0.2.0,>=0.1.13 (from llama-index)
#   Downloading llama_index_llms_openai-0.1.22-py3-none-any.whl.metadata (559 bytes)
# Collecting llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.1.6-py3-none-any.whl.metadata (677 bytes)
# Collecting llama-index-program-openai<0.2.0,>=0.1.3 (from llama-index)
#   Downloading llama_index_program_openai-0.1.6-py3-none-any.whl.metadata (715 bytes)
# Collecting llama-index-question-gen-openai<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl.metadata (785 bytes)
# Collecting llama-index-readers-file<0.2.0,>=0.1.4 (from llama-index)
#   Downloading llama_index_readers_file-0.1.25-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-readers-llama-parse<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.1.4-py3-none-any.whl.metadata (3.5 kB)
# Collecting PyYAML>=6.0.1 (from llama-index-core==0.10.44->llama-index)
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting SQLAlchemy>=1.4.49 (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.44->llama-index)
#   Downloading SQLAlchemy-2.0.30-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting aiohttp<4.0.0,>=3.8.6 (from llama-index-core==0.10.44->llama-index)
#   Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Collecting dataclasses-json (from llama-index-core==0.10.44->llama-index)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting deprecated>=1.2.9.3 (from llama-index-core==0.10.44->llama-index)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core==0.10.44->llama-index)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Collecting fsspec>=2023.5.0 (from llama-index-core==0.10.44->llama-index)
#   Downloading fsspec-2024.6.0-py3-none-any.whl.metadata (11 kB)
# Collecting httpx (from llama-index-core==0.10.44->llama-index)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting llamaindex-py-client<0.2.0,>=0.1.18 (from llama-index-core==0.10.44->llama-index)
#   Downloading llamaindex_py_client-0.1.19-py3-none-any.whl.metadata (760 bytes)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./.venv/lib/python3.10/site-packages (from llama-index-core==0.10.44->llama-index) (1.6.0)
# Collecting networkx>=3.0 (from llama-index-core==0.10.44->llama-index)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting nltk<4.0.0,>=3.8.1 (from llama-index-core==0.10.44->llama-index)
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting numpy (from llama-index-core==0.10.44->llama-index)
#   Downloading numpy-2.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 1.7 MB/s eta 0:00:00
# Collecting openai>=1.1.0 (from llama-index-core==0.10.44->llama-index)
#   Downloading openai-1.34.0-py3-none-any.whl.metadata (21 kB)
# Collecting pandas (from llama-index-core==0.10.44->llama-index)
#   Using cached pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting pillow>=9.0.0 (from llama-index-core==0.10.44->llama-index)
#   Using cached pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting requests>=2.31.0 (from llama-index-core==0.10.44->llama-index)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tenacity<9.0.0,>=8.2.0 (from llama-index-core==0.10.44->llama-index)
#   Using cached tenacity-8.3.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting tiktoken>=0.3.3 (from llama-index-core==0.10.44->llama-index)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting tqdm<5.0.0,>=4.66.1 (from llama-index-core==0.10.44->llama-index)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./.venv/lib/python3.10/site-packages (from llama-index-core==0.10.44->llama-index) (4.12.2)
# Collecting typing-inspect>=0.8.0 (from llama-index-core==0.10.44->llama-index)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting wrapt (from llama-index-core==0.10.44->llama-index)
#   Using cached wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting filelock (from transformers)
#   Downloading filelock-3.15.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting huggingface-hub<1.0,>=0.23.0 (from transformers)
#   Downloading huggingface_hub-0.23.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.10/site-packages (from transformers) (24.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2024.5.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 694.8 kB/s eta 0:00:00a 0:00:01
# Collecting tokenizers<0.20,>=0.19 (from transformers)
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Downloading safetensors-0.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting beautifulsoup4<5.0.0,>=4.12.3 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting pypdf<5.0.0,>=4.0.1 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading pypdf-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse<0.5.0,>=0.4.0 (from llama-index-readers-llama-parse<0.2.0,>=0.1.2->llama-index)
#   Downloading llama_parse-0.4.4-py3-none-any.whl.metadata (3.5 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.31.0->llama-index-core==0.10.44->llama-index)
#   Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests>=2.31.0->llama-index-core==0.10.44->llama-index)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.31.0->llama-index-core==0.10.44->llama-index)
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.31.0->llama-index-core==0.10.44->llama-index)
#   Using cached certifi-2024.6.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama-index)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama-index)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama-index)
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama-index)
#   Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama-index)
#   Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama-index)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Using cached soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting pydantic>=1.10 (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core==0.10.44->llama-index)
#   Downloading pydantic-2.7.4-py3-none-any.whl.metadata (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting anyio (from httpx->llama-index-core==0.10.44->llama-index)
#   Downloading anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting httpcore==1.* (from httpx->llama-index-core==0.10.44->llama-index)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting sniffio (from httpx->llama-index-core==0.10.44->llama-index)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->llama-index-core==0.10.44->llama-index)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting click (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.44->llama-index)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting joblib (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.44->llama-index)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting distro<2,>=1.7.0 (from openai>=1.1.0->llama-index-core==0.10.44->llama-index)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting greenlet!=0.4.17 (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.44->llama-index)
#   Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core==0.10.44->llama-index)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core==0.10.44->llama-index)
#   Downloading marshmallow-3.21.3-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.10/site-packages (from pandas->llama-index-core==0.10.44->llama-index) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->llama-index-core==0.10.44->llama-index)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->llama-index-core==0.10.44->llama-index)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.10/site-packages (from anyio->httpx->llama-index-core==0.10.44->llama-index) (1.2.1)
# Collecting annotated-types>=0.4.0 (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core==0.10.44->llama-index)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.18.4 (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core==0.10.44->llama-index)
#   Downloading pydantic_core-2.18.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core==0.10.44->llama-index) (1.16.0)
# Downloading llama_index-0.10.45-py3-none-any.whl (6.8 kB)
# Downloading llama_index_core-0.10.44-py3-none-any.whl (15.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 4.0 MB/s eta 0:00:0000:0100:01
# Downloading transformers-4.41.2-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 3.7 MB/s eta 0:00:0000:0100:01
# Downloading huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.6/402.6 kB 4.2 MB/s eta 0:00:0000:0100:01
# Downloading llama_index_agent_openai-0.2.7-py3-none-any.whl (12 kB)
# Downloading llama_index_cli-0.1.12-py3-none-any.whl (26 kB)
# Downloading llama_index_embeddings_openai-0.1.10-py3-none-any.whl (6.2 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.1.6-py3-none-any.whl (6.7 kB)
# Downloading llama_index_legacy-0.9.48-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 3.7 MB/s eta 0:00:0000:0100:01
# Downloading llama_index_llms_openai-0.1.22-py3-none-any.whl (11 kB)
# Downloading llama_index_multi_modal_llms_openai-0.1.6-py3-none-any.whl (5.8 kB)
# Downloading llama_index_program_openai-0.1.6-py3-none-any.whl (5.2 kB)
# Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_file-0.1.25-py3-none-any.whl (37 kB)
# Downloading llama_index_readers_llama_parse-0.1.4-py3-none-any.whl (2.5 kB)
# Downloading numpy-2.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 3.9 MB/s eta 0:00:0000:0100:01
# Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 4.6 MB/s eta 0:00:00a 0:00:01
# Downloading regex-2024.5.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (775 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.1/775.1 kB 5.3 MB/s eta 0:00:00a 0:00:01
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading safetensors-0.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 4.1 MB/s eta 0:00:0000:0100:01
# Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 4.6 MB/s eta 0:00:0000:0100:01m
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Downloading filelock-3.15.1-py3-none-any.whl (15 kB)
# Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.8 MB/s eta 0:00:0000:0100:01
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached certifi-2024.6.2-py3-none-any.whl (164 kB)
# Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading fsspec-2024.6.0-py3-none-any.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.9/176.9 kB 2.4 MB/s eta 0:00:00 0:00:01
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Downloading llama_parse-0.4.4-py3-none-any.whl (8.0 kB)
# Downloading llamaindex_py_client-0.1.19-py3-none-any.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 4.6 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.4 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.9 MB/s eta 0:00:00
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 3.2 MB/s eta 0:00:0000:0100:01
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 3.4 MB/s eta 0:00:0000:0100:01
# Downloading openai-1.34.0-py3-none-any.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 6.1 MB/s eta 0:00:00ta 0:00:01
# Using cached pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
# Downloading pypdf-4.2.0-py3-none-any.whl (290 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 4.1 MB/s eta 0:00:00a 0:00:01
# Downloading SQLAlchemy-2.0.30-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 3.3 MB/s eta 0:00:0000:0100:01
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Using cached tenacity-8.3.0-py3-none-any.whl (25 kB)
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 3.5 MB/s eta 0:00:00a 0:00:01
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Using cached wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading anyio-4.4.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 2.6 MB/s eta 0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.5/239.5 kB 3.7 MB/s eta 0:00:00a 0:00:01
# Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (616 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.0/616.0 kB 3.2 MB/s eta 0:00:00a 0:00:01
# Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 2.9 MB/s eta 0:00:00
# Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 kB 5.0 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pydantic-2.7.4-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.0/409.0 kB 3.9 MB/s eta 0:00:00a 0:00:01
# Downloading pydantic_core-2.18.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 3.9 MB/s eta 0:00:00a 0:00:01
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.6/301.6 kB 6.7 MB/s eta 0:00:00:00:01
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 613.7 kB/s eta 0:00:00a 0:00:01
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: striprtf, pytz, dirtyjson, wrapt, urllib3, tzdata, tqdm, tenacity, soupsieve, sniffio, safetensors, regex, PyYAML, pypdf, pydantic-core, pillow, numpy, networkx, mypy-extensions, multidict, marshmallow, joblib, idna, h11, greenlet, fsspec, frozenlist, filelock, distro, click, charset-normalizer, certifi, attrs, async-timeout, annotated-types, yarl, typing-inspect, SQLAlchemy, requests, pydantic, pandas, nltk, httpcore, deprecated, beautifulsoup4, anyio, aiosignal, tiktoken, huggingface-hub, httpx, dataclasses-json, aiohttp, tokenizers, openai, llamaindex-py-client, transformers, llama-index-legacy, llama-index-core, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama-index
# Successfully installed PyYAML-6.0.1 SQLAlchemy-2.0.30 aiohttp-3.9.5 aiosignal-1.3.1 annotated-types-0.7.0 anyio-4.4.0 async-timeout-4.0.3 attrs-23.2.0 beautifulsoup4-4.12.3 certifi-2024.6.2 charset-normalizer-3.3.2 click-8.1.7 dataclasses-json-0.6.7 deprecated-1.2.14 dirtyjson-1.0.8 distro-1.9.0 filelock-3.15.1 frozenlist-1.4.1 fsspec-2024.6.0 greenlet-3.0.3 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 huggingface-hub-0.23.4 idna-3.7 joblib-1.4.2 llama-index-0.10.45 llama-index-agent-openai-0.2.7 llama-index-cli-0.1.12 llama-index-core-0.10.44 llama-index-embeddings-openai-0.1.10 llama-index-indices-managed-llama-cloud-0.1.6 llama-index-legacy-0.9.48 llama-index-llms-openai-0.1.22 llama-index-multi-modal-llms-openai-0.1.6 llama-index-program-openai-0.1.6 llama-index-question-gen-openai-0.1.3 llama-index-readers-file-0.1.25 llama-index-readers-llama-parse-0.1.4 llama-parse-0.4.4 llamaindex-py-client-0.1.19 marshmallow-3.21.3 multidict-6.0.5 mypy-extensions-1.0.0 networkx-3.3 nltk-3.8.1 numpy-2.0.0 openai-1.34.0 pandas-2.2.2 pillow-10.3.0 pydantic-2.7.4 pydantic-core-2.18.4 pypdf-4.2.0 pytz-2024.1 regex-2024.5.15 requests-2.32.3 safetensors-0.4.3 sniffio-1.3.1 soupsieve-2.5 striprtf-0.0.26 tenacity-8.3.0 tiktoken-0.7.0 tokenizers-0.19.1 tqdm-4.66.4 transformers-4.41.2 typing-inspect-0.9.0 tzdata-2024.1 urllib3-2.2.1 wrapt-1.16.0 yarl-1.9.4

# %%
from llama_index.llms  import l
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from llama_index.llms  import LlamaCPP
#
# ImportError: cannot import name 'LlamaCPP' from 'llama_index.llms' (unknown location)

# %%
from llama_index.llms import LlamaCPP
from llama_index.embeddings import HuggingFaceEmbedding

llm = LlamaCPP(
    model_path="path/to/your/model/Mixtral_8x7B_Instruct_v0.1.gguf",  # https://huggingface.co/TheBloke/Mixtral-8x7B-Instruct-v0.1-GGUF
    context_window=32000,
    max_new_tokens=1024,
    model_kwargs={'n_gpu_layers': 1},
    verbose=True
)

embedding_model = HuggingFaceEmbedding(model_name="WhereIsAI/UAE-Large-V1")  # https://huggingface.co/WhereIsAI/UAE-Large-V1
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from llama_index.llms import LlamaCPP
#       2 from llama_index.embeddings import HuggingFaceEmbedding
#       4 llm = LlamaCPP(
#       5     model_path="path/to/your/model/Mixtral_8x7B_Instruct_v0.1.gguf",  # https://huggingface.co/TheBloke/Mixtral-8x7B-Instruct-v0.1-GGUF
#       6     context_window=32000,
#    (...)
#       9     verbose=True
#      10 )
#
# ImportError: cannot import name 'LlamaCPP' from 'llama_index.llms' (unknown location)

# %%
from transformers import AutoTokenizer
from llama_index import set_global_tokenizer

set_global_tokenizer(
    AutoTokenizer.from_pretrained("mistralai/Mixtral-8x7B-Instruct-v0.1").encode  # pass in the HuggingFace model org + repo
)

# %%
from llama_index import ServiceContext

service_context = ServiceContext.from_defaults(
    llm=llm,
    embed_model=embedding_model,
    system_prompt='You are a bot that answers questions about podcast transcripts'
)

# %%
from pathib import Path
import glob
from llama_index import SimpleDirectoryReader, VectorStoreIndex

# Find all files that match the pattern "*transcript*" using the Python standard library glob module
transcript_files = glob.glob(str(Path(transcript_directory) / '**/*transcript*'), recursive=True)

documents = SimpleDirectoryReader(input_files=transcript_files).load_data()

# We pass in the service context we instantiated earlier (powered by our open-source LLM)
index = VectorStoreIndex.from_documents(documents, service_context=service_context, show_progress=True)
